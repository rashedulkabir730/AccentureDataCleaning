# %%
import pandas as pd

# %%
content = pd.read_csv(r"C:\Users\19178\OneDrive\Documents\Downloads\datasets\Content.csv")
reactions = pd.read_csv(r"C:\Users\19178\OneDrive\Documents\Downloads\datasets\Reactions.csv")
rtypes = pd.read_csv(r"C:\Users\19178\OneDrive\Documents\Downloads\datasets\ReactionTypes.csv")

# %%
content.head()
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2           2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3           3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4           4  01ab84dd-6364-4236-abbb-3f237db77180
#
#                                 User ID   Type        Category  \
# 0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo        Studying
# 1  beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo  healthy eating
# 2  a5c65404-5894-4b87-82f2-d787cbee86b4  photo  healthy eating
# 3  9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo      technology
# 4  e206e31b-5f85-4964-b6ea-d7ee5324def1  video            food
#
#                                                  URL
# 0  https://socialbuzz.cdn.com/content/storage/975...
# 1  https://socialbuzz.cdn.com/content/storage/9f7...
# 2  https://socialbuzz.cdn.com/content/storage/230...
# 3  https://socialbuzz.cdn.com/content/storage/356...
# ...

# %%
reactions.head()
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2           2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3           3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4           4  97522e57-d9ab-4bd6-97bf-c24d952602d2
#
#                                 User ID     Type             Datetime
# 0                                   NaN      NaN  2021-04-22 15:17:15
# 1  5d454588-283d-459d-915d-c48a2cb4c27f  disgust  2020-11-07 09:43:50
# 2  92b87fa5-f271-43e0-af66-84fac21052e6  dislike  2021-06-17 12:22:51
# 3  163daa38-8b77-48c9-9af6-37a6c1447ac2   scared  2021-04-18 05:13:58
# 4  34e8add9-0206-47fd-a501-037b994650a2  disgust  2021-01-06 19:13:01

# %%
rtypes.head()
# Out:
#    Unnamed: 0        Type Sentiment  Score
# 0           0       heart  positive     60
# 1           1        want  positive     70
# 2           2     disgust  negative      0
# 3           3        hate  negative      5
# 4           4  interested  positive     30

# %% [markdown]
# ### check for missing values

# %%
missing_values_count = content.isnull().sum()
missing_values_count
# Out:
# Unnamed: 0      0
# Content ID      0
# User ID         0
# Type            0
# Category        0
# URL           199
# dtype: int64

# %%
missing_values_count = reactions.isnull().sum()
missing_values_count
# Out:
# Unnamed: 0       0
# Content ID       0
# User ID       3019
# Type           980
# Datetime         0
# dtype: int64

# %%
missing_values_count = rtypes.isnull().sum()
missing_values_count
# Out:
# Unnamed: 0    0
# Type          0
# Sentiment     0
# Score         0
# dtype: int64

# %%
#drop na values in type for reactions df

reactions_cleaned = reactions.dropna(subset=['Type'])

# %%
reactions_cleaned.shape
reactions_cleaned.head()
# Out:
#    Unnamed: 0                            Content ID  \
# 1           1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2           2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3           3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4           4  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 5           5  97522e57-d9ab-4bd6-97bf-c24d952602d2
#
#                                 User ID        Type             Datetime
# 1  5d454588-283d-459d-915d-c48a2cb4c27f     disgust  2020-11-07 09:43:50
# 2  92b87fa5-f271-43e0-af66-84fac21052e6     dislike  2021-06-17 12:22:51
# 3  163daa38-8b77-48c9-9af6-37a6c1447ac2      scared  2021-04-18 05:13:58
# 4  34e8add9-0206-47fd-a501-037b994650a2     disgust  2021-01-06 19:13:01
# 5  9b6d35f9-5e15-4cd0-a8d7-b1f3340e02c4  interested  2020-08-23 12:25:58

# %% [markdown]
# ## check data types for each column in each df

# %%
print(reactions_cleaned.dtypes)
# Out:
# Unnamed: 0     int64
# Content ID    object
# User ID       object
# Type          object
# Datetime      object
# dtype: object

# %%
#change datetime data type

reactions_cleaned['Datetime'] = pd.to_datetime(reactions_cleaned['Datetime'])
# Out:
# <ipython-input-62-d86f377b9a2d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reactions_cleaned['Datetime'] = pd.to_datetime(reactions_cleaned['Datetime'])

# %%
print(reactions_cleaned.dtypes)
# Out:
# Unnamed: 0             int64
# Content ID            object
# User ID               object
# Type                  object
# Datetime      datetime64[ns]
# dtype: object

# %%
print(content.dtypes)
# Out:
# Unnamed: 0     int64
# Content ID    object
# User ID       object
# Type          object
# Category      object
# URL           object
# dtype: object

# %%
#drop Unnamed: 0  column in all dataframes

# %%
#del reactions_cleaned["Unnamed: 0"]

# %%
#del rtypes["Unnamed: 0"]

# %%
#del content["Unnamed: 0"]

# %% [markdown]
# ## drop unneeded columms

# %%
reactions_cleaned = reactions_cleaned.drop(columns=[ 'User ID'])

# %%
content = content.drop(columns=[ 'User ID'])

# %% [markdown]
# ## check for inconsistent values in columns

# %%
unique = content['Type'].unique()
print(unique)
# Out:
# ['photo' 'video' 'GIF' 'audio']

# %%
unique = content['Category'].unique()
print(unique)
# Out:
# ['Studying' 'healthy eating' 'technology' 'food' 'cooking' 'dogs' 'soccer'
#  'public speaking' 'science' 'tennis' 'travel' 'fitness' 'education'
#  'studying' 'veganism' 'Animals' 'animals' 'culture' '"culture"' 'Fitness'
#  '"studying"' 'Veganism' '"animals"' 'Travel' '"soccer"' 'Education'
#  '"dogs"' 'Technology' 'Soccer' '"tennis"' 'Culture' '"food"' 'Food'
#  '"technology"' 'Healthy Eating' '"cooking"' 'Science' '"public speaking"'
#  '"veganism"' 'Public Speaking' '"science"']

# %%
#makes all values lowercase
#remove double quotes 

content['Category'] = content['Category'].str.lower()

# %%
content['Category'] = content['Category'].str.strip('""')

# %%
unique = content['Category'].unique()
print(unique)
# Out:
# ['studying' 'healthy eating' 'technology' 'food' 'cooking' 'dogs' 'soccer'
#  'public speaking' 'science' 'tennis' 'travel' 'fitness' 'education'
#  'veganism' 'animals' 'culture']

# %%
unique = reactions_cleaned['Type'].unique()
print(unique)
# Out:
# ['disgust' 'dislike' 'scared' 'interested' 'peeking' 'cherish' 'hate'
#  'love' 'indifferent' 'super love' 'intrigued' 'worried' 'like' 'heart'
#  'want' 'adore']

# %%
reactions_cleaned.head()
# Out:
#    Unnamed: 0                            Content ID        Type  \
# 1           1  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust
# 2           2  97522e57-d9ab-4bd6-97bf-c24d952602d2     dislike
# 3           3  97522e57-d9ab-4bd6-97bf-c24d952602d2      scared
# 4           4  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust
# 5           5  97522e57-d9ab-4bd6-97bf-c24d952602d2  interested
#
#              Datetime
# 1 2020-11-07 09:43:50
# 2 2021-06-17 12:22:51
# 3 2021-04-18 05:13:58
# 4 2021-01-06 19:13:01
# 5 2020-08-23 12:25:58

# %%
content
# Out:
#      Unnamed: 0                            Content ID   Type         Category  \
# 0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2  photo         studying
# 1             1  9f737e0a-3cdd-4d29-9d24-753f4e3be810  photo   healthy eating
# 2             2  230c4e4d-70c3-461d-b42c-ec09396efb3f  photo   healthy eating
# 3             3  356fff80-da4d-4785-9f43-bc1261031dc6  photo       technology
# 4             4  01ab84dd-6364-4236-abbb-3f237db77180  video             food
# ..          ...                                   ...    ...              ...
# 995         995  b4cef9ef-627b-41d7-a051-5961b0204ebb  video  public speaking
# 996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c    GIF       technology
# 997         997  435007a5-6261-4d8b-b0a4-55fdc189754b  audio         veganism
# 998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7    GIF          culture
# 999         999  75d6b589-7fae-4a6d-b0d0-752845150e56  audio       technology
#
# ...

# %%
rtypes
# Out:
#     Unnamed: 0         Type Sentiment  Score
# 0            0        heart  positive     60
# 1            1         want  positive     70
# 2            2      disgust  negative      0
# 3            3         hate  negative      5
# 4            4   interested  positive     30
# 5            5  indifferent   neutral     20
# 6            6         love  positive     65
# 7            7   super love  positive     75
# 8            8      cherish  positive     70
# 9            9        adore  positive     72
# 10          10         like  positive     50
# 11          11      dislike  negative     10
# 12          12    intrigued  positive     45
# 13          13      peeking   neutral     35
# 14          14       scared  negative     15
# 15          15      worried  negative     12

# %%
rtypes = rtypes.rename(columns={'Type': 'Reaction_type'})

# %%
result_outer = pd.merge(reactions_cleaned, content, on='Content ID', how='outer')

# %%
result_outer.head()
# Out:
#    Unnamed: 0_x                            Content ID      Type_x  \
# 0           1.0  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust
# 1           2.0  97522e57-d9ab-4bd6-97bf-c24d952602d2     dislike
# 2           3.0  97522e57-d9ab-4bd6-97bf-c24d952602d2      scared
# 3           4.0  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust
# 4           5.0  97522e57-d9ab-4bd6-97bf-c24d952602d2  interested
#
#              Datetime  Unnamed: 0_y Type_y  Category  \
# 0 2020-11-07 09:43:50             0  photo  studying
# 1 2021-06-17 12:22:51             0  photo  studying
# 2 2021-04-18 05:13:58             0  photo  studying
# 3 2021-01-06 19:13:01             0  photo  studying
# 4 2020-08-23 12:25:58             0  photo  studying
#
#                                                  URL
# 0  https://socialbuzz.cdn.com/content/storage/975...
# 1  https://socialbuzz.cdn.com/content/storage/975...
# 2  https://socialbuzz.cdn.com/content/storage/975...
# ...

# %%
result_outer = result_outer.rename(columns={'Type_x': 'Reaction_type'})

# %%
result_outer = result_outer.rename(columns={'Type_y': 'Content_type'})

# %%
result_outer.head()
# Out:
#    Unnamed: 0_x                            Content ID Reaction_type  \
# 0           1.0  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 1           2.0  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike
# 2           3.0  97522e57-d9ab-4bd6-97bf-c24d952602d2        scared
# 3           4.0  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 4           5.0  97522e57-d9ab-4bd6-97bf-c24d952602d2    interested
#
#              Datetime  Unnamed: 0_y Content_type  Category  \
# 0 2020-11-07 09:43:50             0        photo  studying
# 1 2021-06-17 12:22:51             0        photo  studying
# 2 2021-04-18 05:13:58             0        photo  studying
# 3 2021-01-06 19:13:01             0        photo  studying
# 4 2020-08-23 12:25:58             0        photo  studying
#
#                                                  URL
# 0  https://socialbuzz.cdn.com/content/storage/975...
# 1  https://socialbuzz.cdn.com/content/storage/975...
# ...

# %%
result_outer = pd.merge(result_outer, rtypes, on='Reaction_type', how='outer')

# %%
result_outer.head()
# Out:
#    Unnamed: 0_x                            Content ID Reaction_type  \
# 0           1.0  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 1           4.0  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 2          35.0  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 3          52.0  9f737e0a-3cdd-4d29-9d24-753f4e3be810       disgust
# 4          88.0  230c4e4d-70c3-461d-b42c-ec09396efb3f       disgust
#
#              Datetime  Unnamed: 0_y Content_type        Category  \
# 0 2020-11-07 09:43:50             0        photo        studying
# 1 2021-01-06 19:13:01             0        photo        studying
# 2 2021-04-09 02:46:20             0        photo        studying
# 3 2021-03-28 21:15:26             1        photo  healthy eating
# 4 2020-08-04 05:40:33             2        photo  healthy eating
#
#                                                  URL  Unnamed: 0 Sentiment  \
# 0  https://socialbuzz.cdn.com/content/storage/975...         2.0  negative
# ...

# %%
csv_file_path = r"C:\Users\19178\OneDrive\Documents\Downloads\datasets\accenture_final.csv"
result_outer.to_csv(csv_file_path, index=False)

# %%
top_5 = result_outer.groupby("Category").sum()

# %%
top_5.sort_values(by='Score', ascending=False).head(5)
# Out:
#                 Unnamed: 0_x  Unnamed: 0_y  Unnamed: 0    Score
# Category
# animals           26444291.0       1028773     14298.0  74965.0
# science           26163332.0       1020473     13315.0  71168.0
# healthy eating    20769958.0        807605     12624.0  69339.0
# technology        21769618.0        846515     12357.0  68738.0
# food              20877178.0        813250     12484.0  66676.0
